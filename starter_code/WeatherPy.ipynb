# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key
from api_keys import g_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 575

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Base URL
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter 
record = 0
sets = 1

# Weather DataFrame 
weather_df = pd.DataFrame({"City": cities})
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""

# Interate through citirs and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    # Print url 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | ulladulla.
# Processing Record 1  of Set 1 | tiksi.
# Processing Record 2  of Set 1 | saskylakh.
# Processing Record 3  of Set 1 | saint george.
# Processing Record 4  of Set 1 | sawakin.
# Processing Record 5  of Set 1 | pacific grove.
# Processing Record 6  of Set 1 | rikitea.
# Processing Record 7  of Set 1 | gat.
# Processing Record 8  of Set 1 | meyungs.
# City not found...skipping meyungs.
# Processing Record 9  of Set 1 | marsa matruh.
# Processing Record 10  of Set 1 | jamestown.
# Processing Record 11  of Set 1 | new norfolk.
# Processing Record 12  of Set 1 | hobart.
# Processing Record 13  of Set 1 | khuzhir.
# Processing Record 14  of Set 1 | antofagasta.
# Processing Record 15  of Set 1 | duyun.
# Processing Record 16  of Set 1 | khatanga.
# Processing Record 17  of Set 1 | vila.
# Processing Record 18  of Set 1 | hunchun.
# Processing Record 19  of Set 1 | mataura.
# Processing Record 20  of Set 1 | neiafu.
# Processing Record 21  of Set 1 | hofn.
# Processing Record 22  of Set 1 | mount isa.
# Processing Record 23  of Set 1 | souillac.
# Processing Record 24  of Set 1 | guerrero negro.
# Processing Record 25  of Set 1 | port elizabeth.
# Processing Record 26  of Set 1 | albany.
# Processing Record 27  of Set 1 | punta arenas.
# Processing Record 28  of Set 1 | provideniya.
# Processing Record 29  of Set 1 | yueyang.
# Processing Record 30  of Set 1 | bengkalis.
# City not found...skipping bengkalis.
# Processing Record 31  of Set 1 | waitati.
# Processing Record 32  of Set 1 | ushuaia.
# Processing Record 33  of Set 1 | vaini.
# Processing Record 34  of Set 1 | jardim.
# Processing Record 35  of Set 1 | kapaa.
# Processing Record 36  of Set 1 | nioro.
# Processing Record 37  of Set 1 | batavia.
# Processing Record 38  of Set 1 | longyearbyen.
# Processing Record 39  of Set 1 | port lincoln.
# Processing Record 40  of Set 1 | atuona.
# Processing Record 41  of Set 1 | ahipara.
# Processing Record 42  of Set 1 | okato.
# Processing Record 43  of Set 1 | ribeira grande.
# Processing Record 44  of Set 1 | hami.
# Processing Record 45  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 46  of Set 1 | bambous virieux.
# Processing Record 47  of Set 1 | carnarvon.
# Processing Record 48  of Set 1 | tarazona.
# Processing Record 49  of Set 1 | bluff.
# Processing Record 0  of Set 2 | henties bay.
# Processing Record 1  of Set 2 | hay river.
# Processing Record 2  of Set 2 | cape town.
# Processing Record 3  of Set 2 | arraial do cabo.
# Processing Record 4  of Set 2 | mazagao.
# Processing Record 5  of Set 2 | chuy.
# Processing Record 6  of Set 2 | mar del plata.
# Processing Record 7  of Set 2 | verkhnetulomskiy.
# Processing Record 8  of Set 2 | vardo.
# Processing Record 9  of Set 2 | dharchula.
# Processing Record 10  of Set 2 | ustyuzhna.
# Processing Record 11  of Set 2 | hilo.
# Processing Record 12  of Set 2 | bengkulu.
# Processing Record 13  of Set 2 | faanui.
# Processing Record 14  of Set 2 | deputatskiy.
# Processing Record 15  of Set 2 | vila franca do campo.
# Processing Record 16  of Set 2 | yirol.
# City not found...skipping yirol.
# Processing Record 17  of Set 2 | east london.
# Processing Record 18  of Set 2 | alofi.
# Processing Record 19  of Set 2 | linden.
# Processing Record 20  of Set 2 | saint-augustin.
# Processing Record 21  of Set 2 | busselton.
# Processing Record 22  of Set 2 | hermanus.
# Processing Record 23  of Set 2 | larap.
# Processing Record 24  of Set 2 | moerai.
# Processing Record 25  of Set 2 | klaksvik.
# Processing Record 26  of Set 2 | san andres.
# Processing Record 27  of Set 2 | pangnirtung.
# Processing Record 28  of Set 2 | yellowknife.
# Processing Record 29  of Set 2 | corinto.
# Processing Record 30  of Set 2 | verkhoyansk.
# Processing Record 31  of Set 2 | mangrol.
# Processing Record 32  of Set 2 | valparaiso.
# Processing Record 33  of Set 2 | kochubey.
# Processing Record 34  of Set 2 | ancud.
# Processing Record 35  of Set 2 | avarua.
# Processing Record 36  of Set 2 | bredasdorp.
# Processing Record 37  of Set 2 | businga.
# Processing Record 38  of Set 2 | puerto ayora.
# Processing Record 39  of Set 2 | satellite beach.
# Processing Record 40  of Set 2 | georgetown.
# Processing Record 41  of Set 2 | airai.
# Processing Record 42  of Set 2 | dunedin.
# Processing Record 43  of Set 2 | alta floresta.
# Processing Record 44  of Set 2 | luderitz.
# Processing Record 45  of Set 2 | vila velha.
# Processing Record 46  of Set 2 | saint-francois.
# Processing Record 47  of Set 2 | mae sai.
# Processing Record 48  of Set 2 | kaitangata.
# Processing Record 49  of Set 2 | duz.
# City not found...skipping duz.
# Processing Record 0  of Set 3 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 1  of Set 3 | pervomayskoye.
# Processing Record 2  of Set 3 | los andes.
# Processing Record 3  of Set 3 | ponta do sol.
# Processing Record 4  of Set 3 | sorland.
# Processing Record 5  of Set 3 | barrow.
# Processing Record 6  of Set 3 | ossora.
# Processing Record 7  of Set 3 | meulaboh.
# Processing Record 8  of Set 3 | inhambane.
# Processing Record 9  of Set 3 | biak.
# Processing Record 10  of Set 3 | borba.
# Processing Record 11  of Set 3 | phan rang.
# City not found...skipping phan rang.
# Processing Record 12  of Set 3 | leningradskiy.
# Processing Record 13  of Set 3 | nouadhibou.
# Processing Record 14  of Set 3 | utiroa.
# City not found...skipping utiroa.
# Processing Record 15  of Set 3 | lorengau.
# Processing Record 16  of Set 3 | szentkiralyszabadja.
# Processing Record 17  of Set 3 | jumla.
# Processing Record 18  of Set 3 | kununurra.
# Processing Record 19  of Set 3 | butaritari.
# Processing Record 20  of Set 3 | saint-philippe.
# Processing Record 21  of Set 3 | cherskiy.
# Processing Record 22  of Set 3 | constitucion.
# Processing Record 23  of Set 3 | fomboni.
# Processing Record 24  of Set 3 | severo-kurilsk.
# Processing Record 25  of Set 3 | chimbote.
# Processing Record 26  of Set 3 | mabaruma.
# Processing Record 27  of Set 3 | port alfred.
# Processing Record 28  of Set 3 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 29  of Set 3 | flin flon.
# Processing Record 30  of Set 3 | makung.
# City not found...skipping makung.
# Processing Record 31  of Set 3 | koumac.
# Processing Record 32  of Set 3 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 33  of Set 3 | buala.
# Processing Record 34  of Set 3 | wuwei.
# Processing Record 35  of Set 3 | grindavik.
# Processing Record 36  of Set 3 | zheleznodorozhnyy.
# Processing Record 37  of Set 3 | narrabri.
# Processing Record 38  of Set 3 | caravelas.
# Processing Record 39  of Set 3 | esperance.
# Processing Record 40  of Set 3 | yerbogachen.
# Processing Record 41  of Set 3 | anadyr.
# Processing Record 42  of Set 3 | bourail.
# Processing Record 43  of Set 3 | pelileo.
# Processing Record 44  of Set 3 | kushmurun.
# Processing Record 45  of Set 3 | boguchany.
# Processing Record 46  of Set 3 | mahebourg.
# Processing Record 47  of Set 3 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 48  of Set 3 | te anau.
# Processing Record 49  of Set 3 | krasnogorskiy.
# Processing Record 0  of Set 4 | aykhal.
# Processing Record 1  of Set 4 | fairbanks.
# Processing Record 2  of Set 4 | samarai.
# Processing Record 3  of Set 4 | amderma.
# City not found...skipping amderma.
# Processing Record 4  of Set 4 | acuna.
# City not found...skipping acuna.
# Processing Record 5  of Set 4 | owando.
# Processing Record 6  of Set 4 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 7  of Set 4 | castro.
# Processing Record 8  of Set 4 | cayenne.
# Processing Record 9  of Set 4 | lima.
# Processing Record 10  of Set 4 | sakakah.
# Processing Record 11  of Set 4 | saldanha.
# Processing Record 12  of Set 4 | sur.
# Processing Record 13  of Set 4 | aksarka.
# Processing Record 14  of Set 4 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 15  of Set 4 | kyrksaeterora.
# Processing Record 16  of Set 4 | chanika.
# Processing Record 17  of Set 4 | sampit.
# Processing Record 18  of Set 4 | vostok.
# Processing Record 19  of Set 4 | mao.
# Processing Record 20  of Set 4 | mehran.
# Processing Record 21  of Set 4 | zaplavnoye.
# Processing Record 22  of Set 4 | yulara.
# Processing Record 23  of Set 4 | sena madureira.
# Processing Record 24  of Set 4 | marsh harbour.
# Processing Record 25  of Set 4 | atar.
# Processing Record 26  of Set 4 | thompson.
# Processing Record 27  of Set 4 | luza.
# Processing Record 28  of Set 4 | valdivia.
# Processing Record 29  of Set 4 | kruisfontein.
# Processing Record 30  of Set 4 | samusu.
# City not found...skipping samusu.
# Processing Record 31  of Set 4 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 32  of Set 4 | upernavik.
# Processing Record 33  of Set 4 | chapais.
# Processing Record 34  of Set 4 | norman wells.
# Processing Record 35  of Set 4 | inuvik.
# Processing Record 36  of Set 4 | arman.
# Processing Record 37  of Set 4 | codrington.
# Processing Record 38  of Set 4 | kodiak.
# Processing Record 39  of Set 4 | tsabong.
# Processing Record 40  of Set 4 | hasaki.
# Processing Record 41  of Set 4 | coquimbo.
# Processing Record 42  of Set 4 | sao filipe.
# Processing Record 43  of Set 4 | sungaipenuh.
# Processing Record 44  of Set 4 | ostrovnoy.
# Processing Record 45  of Set 4 | dikson.
# Processing Record 46  of Set 4 | shieli.
# Processing Record 47  of Set 4 | jertih.
# Processing Record 48  of Set 4 | wahlstedt.
# Processing Record 49  of Set 4 | aklavik.
# Processing Record 0  of Set 5 | yenagoa.
# Processing Record 1  of Set 5 | sorvag.
# City not found...skipping sorvag.
# Processing Record 2  of Set 5 | narsaq.
# Processing Record 3  of Set 5 | katsuura.
# Processing Record 4  of Set 5 | victoria.
# Processing Record 5  of Set 5 | kaeo.
# Processing Record 6  of Set 5 | pevek.
# Processing Record 7  of Set 5 | isangel.
# Processing Record 8  of Set 5 | qaanaaq.
# Processing Record 9  of Set 5 | zaltan.
# Processing Record 10  of Set 5 | beringovskiy.
# Processing Record 11  of Set 5 | zemio.
# Processing Record 12  of Set 5 | azua.
# Processing Record 13  of Set 5 | ibra.
# Processing Record 14  of Set 5 | kathu.
# Processing Record 15  of Set 5 | kasama.
# Processing Record 16  of Set 5 | doka.
# Processing Record 17  of Set 5 | yefira.
# City not found...skipping yefira.
# Processing Record 18  of Set 5 | langham.
# Processing Record 19  of Set 5 | bathsheba.
# Processing Record 20  of Set 5 | svidnik.
# Processing Record 21  of Set 5 | chokurdakh.
# Processing Record 22  of Set 5 | richards bay.
# Processing Record 23  of Set 5 | saint-joseph.
# Processing Record 24  of Set 5 | hithadhoo.
# Processing Record 25  of Set 5 | sorong.
# Processing Record 26  of Set 5 | wanaka.
# Processing Record 27  of Set 5 | torbay.
# Processing Record 28  of Set 5 | zhigansk.
# Processing Record 29  of Set 5 | rio gallegos.
# Processing Record 30  of Set 5 | novobiryusinskiy.
# Processing Record 31  of Set 5 | haibowan.
# City not found...skipping haibowan.
# Processing Record 32  of Set 5 | faya.
# Processing Record 33  of Set 5 | abu dhabi.
# Processing Record 34  of Set 5 | kahului.
# Processing Record 35  of Set 5 | adjumani.
# Processing Record 36  of Set 5 | ferme-neuve.
# Processing Record 37  of Set 5 | nuuk.
# Processing Record 38  of Set 5 | namatanai.
# Processing Record 39  of Set 5 | charters towers.
# Processing Record 40  of Set 5 | scottsburgh.
# City not found...skipping scottsburgh.
# Processing Record 41  of Set 5 | kyshtovka.
# Processing Record 42  of Set 5 | shahumyan.
# Processing Record 43  of Set 5 | poum.
# Processing Record 44  of Set 5 | maglajani.
# Processing Record 45  of Set 5 | havoysund.
# Processing Record 46  of Set 5 | san nicolas.
# Processing Record 47  of Set 5 | skalistyy.
# City not found...skipping skalistyy.
# Processing Record 48  of Set 5 | lebu.
# Processing Record 49  of Set 5 | morros.
# Processing Record 0  of Set 6 | port keats.
# Processing Record 1  of Set 6 | quzhou.
# Processing Record 2  of Set 6 | bow island.
# Processing Record 3  of Set 6 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 4  of Set 6 | bontang.
# Processing Record 5  of Set 6 | vershino-shakhtaminskiy.
# Processing Record 6  of Set 6 | tuatapere.
# Processing Record 7  of Set 6 | beloha.
# Processing Record 8  of Set 6 | dingle.
# Processing Record 9  of Set 6 | erdenet.
# Processing Record 10  of Set 6 | huarmey.
# Processing Record 11  of Set 6 | santa maria.
# Processing Record 12  of Set 6 | kavaratti.
# Processing Record 13  of Set 6 | tuktoyaktuk.
# Processing Record 14  of Set 6 | cabedelo.
# Processing Record 15  of Set 6 | boundiali.
# Processing Record 16  of Set 6 | zonguldak.
# Processing Record 17  of Set 6 | nikolskoye.
# Processing Record 18  of Set 6 | madang.
# Processing Record 19  of Set 6 | yining.
# Processing Record 20  of Set 6 | hambantota.
# Processing Record 21  of Set 6 | rocha.
# Processing Record 22  of Set 6 | acapulco.
# Processing Record 23  of Set 6 | solnechnyy.
# Processing Record 24  of Set 6 | nykoping.
# Processing Record 25  of Set 6 | margate.
# Processing Record 26  of Set 6 | vestmannaeyjar.
# Processing Record 27  of Set 6 | college.
# Processing Record 28  of Set 6 | manono.
# Processing Record 29  of Set 6 | port augusta.
# Processing Record 30  of Set 6 | roald.
# Processing Record 31  of Set 6 | mecca.
# Processing Record 32  of Set 6 | glogova.
# Processing Record 33  of Set 6 | glendive.
# Processing Record 34  of Set 6 | pershotravneve.
# Processing Record 35  of Set 6 | trelew.
# Processing Record 36  of Set 6 | clyde river.
# Processing Record 37  of Set 6 | saleaula.
# City not found...skipping saleaula.
# Processing Record 38  of Set 6 | kendari.
# Processing Record 39  of Set 6 | karratha.
# Processing Record 40  of Set 6 | asau.
# Processing Record 41  of Set 6 | san patricio.
# Processing Record 42  of Set 6 | broome.
# Processing Record 43  of Set 6 | hovd.
# Processing Record 44  of Set 6 | kysyl-syr.
# Processing Record 45  of Set 6 | severnoye.
# Processing Record 46  of Set 6 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 47  of Set 6 | linguere.
# Processing Record 48  of Set 6 | iqaluit.
# Processing Record 49  of Set 6 | byron bay.
# Processing Record 0  of Set 7 | los algarrobos.
# Processing Record 1  of Set 7 | forbes.
# Processing Record 2  of Set 7 | cumberland.
# Processing Record 3  of Set 7 | cabo san lucas.
# Processing Record 4  of Set 7 | tungor.
# Processing Record 5  of Set 7 | tasiilaq.
# Processing Record 6  of Set 7 | sayyan.
# Processing Record 7  of Set 7 | lagoa.
# Processing Record 8  of Set 7 | mount gambier.
# Processing Record 9  of Set 7 | ulaanbaatar.
# Processing Record 10  of Set 7 | kijang.
# Processing Record 11  of Set 7 | oriximina.
# Processing Record 12  of Set 7 | dahra.
# Processing Record 13  of Set 7 | yakeshi.
# Processing Record 14  of Set 7 | tiznit.
# Processing Record 15  of Set 7 | ampere.
# Processing Record 16  of Set 7 | dunshaughlin.
# Processing Record 17  of Set 7 | christchurch.
# Processing Record 18  of Set 7 | alice springs.
# Processing Record 19  of Set 7 | pisco.
# Processing Record 20  of Set 7 | sistranda.
# Processing Record 21  of Set 7 | nikki.
# Processing Record 22  of Set 7 | evensk.
# Processing Record 23  of Set 7 | lichtenburg.
# Processing Record 24  of Set 7 | abnub.
# Processing Record 25  of Set 7 | waddan.
# Processing Record 26  of Set 7 | bethel.
# Processing Record 27  of Set 7 | bahraich.
# Processing Record 28  of Set 7 | taoudenni.
# Processing Record 29  of Set 7 | kalabo.
# Processing Record 30  of Set 7 | ambulu.
# Processing Record 31  of Set 7 | agirish.
# Processing Record 32  of Set 7 | linjiang.
# Processing Record 33  of Set 7 | venado.
# Processing Record 34  of Set 7 | nkhotakota.
# Processing Record 35  of Set 7 | pucallpa.
# Processing Record 36  of Set 7 | tahoua.
# Processing Record 37  of Set 7 | waingapu.
# Processing Record 38  of Set 7 | egvekinot.
# Processing Record 39  of Set 7 | odweyne.
# Processing Record 40  of Set 7 | maues.
# Processing Record 41  of Set 7 | tual.
# Processing Record 42  of Set 7 | kandrian.
# Processing Record 43  of Set 7 | sobolevo.
# Processing Record 44  of Set 7 | gorele.
# Processing Record 45  of Set 7 | port-gentil.
# Processing Record 46  of Set 7 | temaraia.
# City not found...skipping temaraia.
# Processing Record 47  of Set 7 | guaratinga.
# Processing Record 48  of Set 7 | bilma.
# Processing Record 49  of Set 7 | kavieng.
# Processing Record 0  of Set 8 | noyabrsk.
# Processing Record 1  of Set 8 | itarema.
# Processing Record 2  of Set 8 | borzna.
# Processing Record 3  of Set 8 | luanda.
# Processing Record 4  of Set 8 | hualmay.
# Processing Record 5  of Set 8 | ulety.
# Processing Record 6  of Set 8 | nyaunglebin.
# Processing Record 7  of Set 8 | lata.
# Processing Record 8  of Set 8 | guaimaro.
# Processing Record 9  of Set 8 | port hardy.
# Processing Record 10  of Set 8 | wampusirpi.
# City not found...skipping wampusirpi.
# Processing Record 11  of Set 8 | raymondville.
# Processing Record 12  of Set 8 | omutinskoye.
# City not found...skipping omutinskoye.
# Processing Record 13  of Set 8 | bam.
# Processing Record 14  of Set 8 | usinsk.
# Processing Record 15  of Set 8 | padang.
# Processing Record 16  of Set 8 | virginia beach.
# Processing Record 17  of Set 8 | kodinsk.
# Processing Record 18  of Set 8 | port hawkesbury.
# Processing Record 19  of Set 8 | bani walid.
# Processing Record 20  of Set 8 | bukama.
# Processing Record 21  of Set 8 | yar-sale.
# Processing Record 22  of Set 8 | sao felix do xingu.
# Processing Record 23  of Set 8 | pochutla.
# Processing Record 24  of Set 8 | srednekolymsk.
# Processing Record 25  of Set 8 | bukachacha.
# Processing Record 26  of Set 8 | raudeberg.
# Processing Record 27  of Set 8 | illapel.
# Processing Record 28  of Set 8 | pajapita.
# Processing Record 29  of Set 8 | inhapim.
# Processing Record 30  of Set 8 | marcona.
# City not found...skipping marcona.
# Processing Record 31  of Set 8 | bakchar.
# Processing Record 32  of Set 8 | amga.
# Processing Record 33  of Set 8 | bumba.
# Processing Record 34  of Set 8 | hobyo.
# Processing Record 35  of Set 8 | geraldton.
# Processing Record 36  of Set 8 | cidreira.
# Processing Record 37  of Set 8 | naze.
# Processing Record 38  of Set 8 | fortuna.
# Processing Record 39  of Set 8 | port moresby.
# Processing Record 40  of Set 8 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 41  of Set 8 | tautira.
# Processing Record 42  of Set 8 | vanavara.
# Processing Record 43  of Set 8 | hearst.
# Processing Record 44  of Set 8 | kloulklubed.
# Processing Record 45  of Set 8 | aswan.
# Processing Record 46  of Set 8 | brigantine.
# Processing Record 47  of Set 8 | dargaville.
# Processing Record 48  of Set 8 | garowe.
# Processing Record 49  of Set 8 | tabiauea.
# City not found...skipping tabiauea.
# Processing Record 0  of Set 9 | afmadu.
# City not found...skipping afmadu.
# Processing Record 1  of Set 9 | aripuana.
# Processing Record 2  of Set 9 | tessalit.
# Processing Record 3  of Set 9 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 4  of Set 9 | labrea.
# Processing Record 5  of Set 9 | kungurtug.
# Processing Record 6  of Set 9 | yashkul.
# Processing Record 7  of Set 9 | necochea.
# Processing Record 8  of Set 9 | qaqortoq.
# Processing Record 9  of Set 9 | karamay.
# City not found...skipping karamay.
# Processing Record 10  of Set 9 | aksay.
# Processing Record 11  of Set 9 | san clemente.
# Processing Record 12  of Set 9 | samur.
# Processing Record 13  of Set 9 | kilindoni.
# Processing Record 14  of Set 9 | rancharia.
# Processing Record 15  of Set 9 | santa isabel do rio negro.
# Processing Record 16  of Set 9 | imbituba.
# Processing Record 17  of Set 9 | erenhot.
# Processing Record 18  of Set 9 | vaitape.
# Processing Record 19  of Set 9 | havre-saint-pierre.
# Processing Record 20  of Set 9 | lunca.
# Processing Record 21  of Set 9 | dunmore town.
# Processing Record 22  of Set 9 | calvia.
# Processing Record 23  of Set 9 | berlevag.
# Processing Record 24  of Set 9 | tambura.
# Processing Record 25  of Set 9 | wolmaranstad.
# City not found...skipping wolmaranstad.
# Processing Record 26  of Set 9 | camana.
# Processing Record 27  of Set 9 | koidu.
# Processing Record 28  of Set 9 | butembo.
# Processing Record 29  of Set 9 | talnakh.
# Processing Record 30  of Set 9 | lodja.
# Processing Record 31  of Set 9 | turka.
# Processing Record 32  of Set 9 | novosergiyevka.
# Processing Record 33  of Set 9 | sinnamary.
# Processing Record 34  of Set 9 | carupano.
# Processing Record 35  of Set 9 | haines junction.
# Processing Record 36  of Set 9 | mercedes.
# Processing Record 37  of Set 9 | leon.
# Processing Record 38  of Set 9 | orbetello.
# Processing Record 39  of Set 9 | itoman.
# Processing Record 40  of Set 9 | srandakan.
# Processing Record 41  of Set 9 | superior.
# Processing Record 42  of Set 9 | sumbe.
# Processing Record 43  of Set 9 | bossembele.
# City not found...skipping bossembele.
# Processing Record 44  of Set 9 | najran.
# Processing Record 45  of Set 9 | ondorhaan.
# City not found...skipping ondorhaan.
# Processing Record 46  of Set 9 | altay.
# Processing Record 47  of Set 9 | guider.
# Processing Record 48  of Set 9 | palmerston.
# Processing Record 49  of Set 9 | birao.
# Processing Record 0  of Set 10 | vire.
# Processing Record 1  of Set 10 | puerto narino.
# Processing Record 2  of Set 10 | bolivar.
# Processing Record 3  of Set 10 | ngukurr.
# City not found...skipping ngukurr.
# Processing Record 4  of Set 10 | bongouanou.
# Processing Record 5  of Set 10 | tomatlan.
# Processing Record 6  of Set 10 | bowen.
# Processing Record 7  of Set 10 | rorvik.
# Processing Record 8  of Set 10 | ihosy.
# Processing Record 9  of Set 10 | saint-georges.
# Processing Record 10  of Set 10 | sahrak.
# City not found...skipping sahrak.
# Processing Record 11  of Set 10 | roma.
# Processing Record 12  of Set 10 | chateaubelair.
# Processing Record 13  of Set 10 | quelimane.
# Processing Record 14  of Set 10 | laguna.
# Processing Record 15  of Set 10 | nanortalik.
# Processing Record 16  of Set 10 | kirakira.
# Processing Record 17  of Set 10 | ordzhonikidze.
# Processing Record 18  of Set 10 | dalbandin.
# Processing Record 19  of Set 10 | chaozhou.
# Processing Record 20  of Set 10 | buqayq.
# City not found...skipping buqayq.
# Processing Record 21  of Set 10 | aleksandrov gay.
# Processing Record 22  of Set 10 | sabha.
# Processing Record 23  of Set 10 | naryan-mar.
# Processing Record 24  of Set 10 | sitka.
# Processing Record 25  of Set 10 | george.
# Processing Record 26  of Set 10 | techiman.
# Processing Record 27  of Set 10 | three hills.
# Processing Record 28  of Set 10 | sao paulo de olivenca.
# Processing Record 29  of Set 10 | brae.
# Processing Record 30  of Set 10 | sosva.
# Processing Record 31  of Set 10 | berbera.
# Processing Record 32  of Set 10 | shu.
# Processing Record 33  of Set 10 | axim.
# Processing Record 34  of Set 10 | porto seguro.
# Processing Record 35  of Set 10 | batemans bay.
# Processing Record 36  of Set 10 | salinas.
# Processing Record 37  of Set 10 | ilulissat.
# Processing Record 38  of Set 10 | thouars.
# Processing Record 39  of Set 10 | tabou.
# Processing Record 40  of Set 10 | palmas bellas.
# Processing Record 41  of Set 10 | smolenka.
# Processing Record 42  of Set 10 | taperoa.
# Processing Record 43  of Set 10 | emba.
# Processing Record 44  of Set 10 | micheweni.
# Processing Record 45  of Set 10 | mana.
# Processing Record 46  of Set 10 | tubuala.
# Processing Record 47  of Set 10 | srbobran.
# Processing Record 48  of Set 10 | umm jarr.
# City not found...skipping umm jarr.
# Processing Record 49  of Set 10 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 0  of Set 11 | yaan.
# Processing Record 1  of Set 11 | matagami.
# Processing Record 2  of Set 11 | pocone.
# Processing Record 3  of Set 11 | kalengwa.
# Processing Record 4  of Set 11 | bolungarvik.
# City not found...skipping bolungarvik.
# Processing Record 5  of Set 11 | voh.
# Processing Record 6  of Set 11 | champerico.
# Processing Record 7  of Set 11 | rurrenabaque.
# Processing Record 8  of Set 11 | dongargaon.
# Processing Record 9  of Set 11 | nantucket.
# Processing Record 10  of Set 11 | soanierana ivongo.
# Processing Record 11  of Set 11 | cloquet.
# Processing Record 12  of Set 11 | artyom.
# Processing Record 13  of Set 11 | salalah.
# Processing Record 14  of Set 11 | khonuu.
# City not found...skipping khonuu.
# Processing Record 15  of Set 11 | bandarbeyla.
# Processing Record 16  of Set 11 | mahajanga.
# Processing Record 17  of Set 11 | paamiut.
# Processing Record 18  of Set 11 | nishihara.
# Processing Record 19  of Set 11 | port blair.
# Processing Record 20  of Set 11 | sulangan.
# Processing Record 21  of Set 11 | locri.
# Processing Record 22  of Set 11 | guaruja.
# Processing Record 23  of Set 11 | bezhta.
# Processing Record 24  of Set 11 | sarangani.
# Processing Record 25  of Set 11 | san quintin.
# Processing Record 26  of Set 11 | paita.
# Processing Record 27  of Set 11 | manga.
# Processing Record 28  of Set 11 | sao joao da barra.
# Processing Record 29  of Set 11 | moose factory.
# Processing Record 30  of Set 11 | hirara.
# Processing Record 31  of Set 11 | tommot.
# Processing Record 32  of Set 11 | diego de almagro.
# Processing Record 33  of Set 11 | dolinsk.
# Processing Record 34  of Set 11 | olanu.
# Processing Record 35  of Set 11 | harper.
# Processing Record 36  of Set 11 | floreffe.
# Processing Record 37  of Set 11 | mandera.
# Processing Record 38  of Set 11 | melbu.
# Processing Record 39  of Set 11 | lucapa.
# Processing Record 40  of Set 11 | kualakapuas.
# Processing Record 41  of Set 11 | batagay-alyta.
# Processing Record 42  of Set 11 | lompoc.
# Processing Record 43  of Set 11 | alihe.
# Processing Record 44  of Set 11 | lolua.
# City not found...skipping lolua.
# Processing Record 45  of Set 11 | sao luis de montes belos.
# Processing Record 46  of Set 11 | cheyenne.
# Processing Record 47  of Set 11 | genhe.
# Processing Record 48  of Set 11 | ucluelet.
# Processing Record 49  of Set 11 | kawalu.
# Processing Record 0  of Set 12 | san cristobal.
# Processing Record 1  of Set 12 | auki.
# Processing Record 2  of Set 12 | kamenskoye.
# City not found...skipping kamenskoye.
# Processing Record 3  of Set 12 | albanel.
# Processing Record 4  of Set 12 | richard toll.
# City not found...skipping richard toll.
# Processing Record 5  of Set 12 | wawa.
# Processing Record 6  of Set 12 | oranjemund.
# Processing Record 7  of Set 12 | petropavl.
# Processing Record 8  of Set 12 | khandyga.
# Processing Record 9  of Set 12 | olafsvik.
# Processing Record 10  of Set 12 | shelburne.
# Processing Record 11  of Set 12 | bubaque.
# Processing Record 12  of Set 12 | chapleau.
# Processing Record 13  of Set 12 | barbar.
# City not found...skipping barbar.
# Processing Record 14  of Set 12 | redondela.
# Processing Record 15  of Set 12 | semnan.
# Processing Record 16  of Set 12 | sechura.
# Processing Record 17  of Set 12 | maningrida.
# Processing Record 18  of Set 12 | sohbatpur.
# Processing Record 19  of Set 12 | sibut.
# Processing Record 20  of Set 12 | gornopravdinsk.
# Processing Record 21  of Set 12 | karasjok.
# Processing Record 22  of Set 12 | umm kaddadah.
# Processing Record 23  of Set 12 | amahai.
# Processing Record 24  of Set 12 | cartagena.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count
weather_df.count()
# Out:
# City                575
# Country             575
# Date                575
# Latitude            575
# Longitude           575
# Cloudiness (%)      575
# Humidity (%)        575
# Max Temp (F)        575
# Wind Speed (mph)    575
# dtype: int64

# %%
# Display DataFrame
weather_df.head()
# Out:
#            City Country                 Date Latitude Longitude  \
# 0     ulladulla      AU  2022-08-24 15:10:27   -35.35  150.4667
# 1         tiksi      RU  2022-08-24 15:10:27  71.6872  128.8694
# 2     saskylakh      RU  2022-08-24 15:10:28  71.9167  114.0833
# 3  saint george      US  2022-08-24 15:10:28  37.1041 -113.5841
# 4       sawakin      SD  2022-08-24 15:10:29  19.1059   37.3321
#
#   Cloudiness (%) Humidity (%) Max Temp (F) Wind Speed (mph)
# 0             71           68       50.036             2.79
# 1             50           82        41.99             2.67
# 2            100           67       43.754             5.17
# 3              0           19      103.694             5.14
# 4             79           59       89.834             1.78

# %%
# Convert the data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float),
facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float),
facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), 
facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float),
facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -0.51x + 88.62
# The r-squared is: -0.7031096368045192
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.7x + 80.56
# The r-squared is: 0.7662357500063318
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 71.64
# The r-squared is: 0.009968985056329559
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.01x + 69.01
# The r-squared is: 0.005133675549064229
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = 0.12x + 55.46
# The r-squared is: 0.06727589299896629
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.09x + 46.32
# The r-squared is: -0.03374778961618228
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.0x + 3.38
# The r-squared is: -0.003129508332241037
# The regression does not display much of a correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
# Out:
# Regression line equation is: y = -0.03x + 2.95
# The r-squared is: -0.15161725506336152
# The regression does not display much of a correlation between the data sets.
